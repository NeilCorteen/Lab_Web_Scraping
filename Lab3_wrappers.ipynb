# %% [markdown]
# # Lab3_wrappers_first attempt

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import getpass

# %%
client_id = str(getpass.getpass('client_id?'))
# Out:
# client_id?········

# %%
client_secret = str(getpass.getpass('client_secret?'))
# Out:
# client_secret?········

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="2618ccc9619a43d4bc75746578e77f93",
                                                           client_secret="4adea0a95cff4a43adaba95a1451bff5"))

# %%
results = sp.search(q="Radiohead", limit=5)

# %%
type(results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Radiohead&type=track&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#        'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#        'id': '4Z8W4fKeB5YxbusRsdQVPb',
#        'name': 'Radiohead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
# ...

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results['tracks']['href']
# Out:
# 'https://api.spotify.com/v1/search?query=Radiohead&type=track&offset=0&limit=5'

# %%
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
# ...

# %%
results['tracks']['limit']
# Out:
# 5

# %%
playlist1 = sp.user_playlist_tracks("Neil T", "3DI5LujjXYYks2Z470bXt8")

# %%
len(playlist1['items'])
# Out:
# 13

# %%
playlist1['items'][0]['track']['id']

for item in playlist1['items']:
    print(item['track']['id'])

my_mini_playlist = []
for item in playlist1['items']:
    my_mini_playlist.append(item['track']['id'])
# Out:
# 2x0RZdkZcD8QRI53XT4GI5
# 7qiZfU4dY1lWllzX7mPBI3
# 2X5GqfR1ACKSe8RigJ8Z9s
# 1GbyYL0B0Mjn3kSbrEwKKI
# 28mwuJqKOjRpqo14GuKSkj
# 4tJ4XL5tLOmt9poOBG0jxQ
# 3q2gRjU2UdOYRDY1p4cNHr
# 7LZoKNMhsZ7qbP1lYGDva8
# 54ThPAIMtncxxVX2gC4baF
# 4drk4h8G9Sl87G9YHwQ4eu
# 55mXuPsEm6aboDIM68RM74
# 2XWjPtKdi5sucFYtVav07d
# 3J0AoQhAufniMrznCRJASD

# %%
my_mini_playlist
# Out:
# ['2x0RZdkZcD8QRI53XT4GI5',
#  '7qiZfU4dY1lWllzX7mPBI3',
#  '2X5GqfR1ACKSe8RigJ8Z9s',
#  '1GbyYL0B0Mjn3kSbrEwKKI',
#  '28mwuJqKOjRpqo14GuKSkj',
#  '4tJ4XL5tLOmt9poOBG0jxQ',
#  '3q2gRjU2UdOYRDY1p4cNHr',
#  '7LZoKNMhsZ7qbP1lYGDva8',
#  '54ThPAIMtncxxVX2gC4baF',
#  '4drk4h8G9Sl87G9YHwQ4eu',
#  '55mXuPsEm6aboDIM68RM74',
#  '2XWjPtKdi5sucFYtVav07d',
#  '3J0AoQhAufniMrznCRJASD']

# %%
sp.audio_features(my_mini_playlist)
# Out:
# [{'danceability': 0.802,
#   'energy': 0.645,
#   'key': 5,
#   'loudness': -6.181,
#   'mode': 0,
#   'speechiness': 0.0715,
#   'acousticness': 0.272,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.376,
#   'tempo': 100.001,
#   'type': 'audio_features',
#   'id': '2x0RZdkZcD8QRI53XT4GI5',
#   'uri': 'spotify:track:2x0RZdkZcD8QRI53XT4GI5',
#   'track_href': 'https://api.spotify.com/v1/tracks/2x0RZdkZcD8QRI53XT4GI5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2x0RZdkZcD8QRI53XT4GI5',
#   'duration_ms': 157202,
#   'time_signature': 4},
#  {'danceability': 0.825,
#   'energy': 0.652,
#   'key': 1,
#   'loudness': -3.183,
#   'mode': 0,
#   'speechiness': 0.0802,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.0931,
#   'valence': 0.931,
#   'tempo': 95.977,
#   'type': 'audio_features',
#   'id': '7qiZfU4dY1lWllzX7mPBI3',
#   'uri': 'spotify:track:7qiZfU4dY1lWllzX7mPBI3',
# ...

# %%
audio_features_mini = pd.DataFrame(sp.audio_features(tracks=my_mini_playlist))

# %%
audio_features_mini.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.802   0.645    5    -6.181     0       0.0715         0.272
# 1         0.825   0.652    1    -3.183     0       0.0802         0.581
# 2         0.592   0.240   11   -16.179     1       0.0330         0.702
# 3         0.460   0.162    5   -17.142     0       0.0335         0.376
# 4         0.384   0.436    5    -7.432     0       0.0282         0.754
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1190    0.376  100.001  audio_features
# 1          0.000000    0.0931    0.931   95.977  audio_features
# 2          0.381000    0.1210    0.333   96.559  audio_features
# 3          0.000013    0.1810    0.102  122.767  audio_features
# 4          0.000005    0.1310    0.153  107.312  audio_features
#
#                        id                                   uri  \
# 0  2x0RZdkZcD8QRI53XT4GI5  spotify:track:2x0RZdkZcD8QRI53XT4GI5
# ...
